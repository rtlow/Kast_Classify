# %% [markdown]
# Creating the figures for the J0906-0848 dwarf binary system paper.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import astropy
import astropy.io.fits as fits
import astropy.units as u

import splat
import kastredux
import kastclassify
# Out:
# Adding 2404 sources from /home/ryan/code/splat/resources/Spectra/Public/SPEX-PRISM/ to spectral database
# Adding 145 sources from /home/ryan/code/splat/resources/Spectra/Public/LRIS-RED/ to spectral database
# Adding 89 sources from /home/ryan/code/splat/resources/Spectra/Public/MAGE/ to spectral database

# %%
data_folder = '/home/ryan/projects/CoolStars/data/RED/'

# %%
sp1_path = data_folder + 'kastRED_J0906-0848A_20191209.fits'
sp1 = kastredux.readSpectrum(sp1_path)
sp1.name = fits.getheader(sp1_path)['OBJECT']

sp2_path = data_folder + 'kastRED_J0906-0848B_20191209.fits'
sp2 = kastredux.readSpectrum(sp2_path)
sp2.name = fits.getheader(sp2_path)['OBJECT'] + ' B'

# %%
sp1.plot()

# %%
sp2.plot()
