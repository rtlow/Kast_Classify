# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

#setting matplotlib parameters
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 

#set matplotlib global font size
matplotlib.rcParams['font.size']=14

# %%
df = pd.read_csv('/home/ryan/projects/data_prods/Kast_classify/Kastclassify_spectra_calculations_20200602-2.csv')

# %%
df
# Out:
#            name                          filename           RA          DEC  \
# 0    J0225+6229  kastRED_J0225+6229_20200203.fits  02:25:26.30   62:29:58.3
# 1    J1300+3038  kastRED_J1300+3038_20200305.fits  13:00:07.31   30:38:58.2
# 2    J1733+1655  kastRED_J1733+1655_20180717.fits  17:33:53.22   16:55:12.8
# 3    J0813-1522  kastRED_J0813-1522_20200204.fits  08:13:18.68  -15:22:38.1
# 4    J1102-1624  kastRED_J1102-1624_20200311.fits  11:02:46.01  -16:24:22.2
# ..          ...                               ...          ...          ...
# 171    HD 87680     kastRED_HD87680_20180121.fits  10:07:14.81   29:14:15.9
# 172   0002+0115  kastRED_J0002+0115_20170813.fits  00:02:06.53   01:15:35.8
# 173   2340+3433  kastRED_J2340+3433_20170813.fits  23:40:22.60   34:33:15.1
# 174   0914+1809  kastRED_J0914+1809_20180307.fits  09:14:41.21   18:09:43.8
# 175  J2254+2527  kastRED_J2254+2527_20180717.fits  22:54:11.40   25:27:56.8
#
#                     OBSDATE     spt  subtype      spt_chi2     spt_scale  \
# 0    2020-02-04T02:55:25.18  sdM7.5      7.5  5.884886e+05  3.755466e-15
# 1    2020-03-06T11:10:41.12    M6.0      6.0  1.501861e+05  7.157666e-15
# 2    2018-07-18T08:19:45.17    M6.0      6.0  1.023361e+07  2.997134e-13
# 3    2020-02-05T07:12:29.07    M5.0      5.0  1.423880e+06  3.292406e-14
# 4    2020-03-12T08:18:03.22    M6.0      6.0  9.481131e+05  1.610719e-14
# ..                      ...     ...      ...           ...           ...
# 171  2018-01-21T10:56:54.43    M0.0      0.0  3.760723e+07  1.816891e-12
# 172  2017-08-13T09:55:11.60    M7.0      7.0  1.056695e+06  5.889889e-15
# 173  2017-08-13T08:15:13.38    M6.0      6.0  1.347700e+06  5.787539e-14
# 174  2018-03-07T06:46:56.69    M5.0      5.0  5.761317e+04  9.238674e-15
# 175  2018-07-18T10:43:27.72    M6.0      6.0  1.225363e+06  1.339627e-14
#
#      lepine2007_CaH3  ...  gizis_TiO5_spt_err  gizis_CaH2_spt  \
# 0           0.595671  ...            0.105648        5.161495
# 1           0.493105  ...            0.062483        6.172466
# 2           0.605642  ...            0.005622        4.814573
# 3           0.740387  ...            0.021971        2.803626
# 4           0.679623  ...            0.019128        4.337889
# ..               ...  ...                 ...             ...
# 171         0.999249  ...                 NaN             NaN
# 172         0.608223  ...            0.033897        5.257908
# 173         0.641881  ...            0.023679        4.474636
# 174         0.638348  ...            0.129862        3.636063
# 175         0.589147  ...            0.017437        5.148737
#
#      gizis_CaH2_spt_err  gizis_CaH3_spt  gizis_CaH3_spt_err      zeta  \
# 0              0.121055        5.077929            0.201199  1.085050
# 1              0.069819        6.924109            0.108992  0.971940
# 2              0.008727        4.898452            0.017384  1.037346
# 3              0.024753        2.473039            0.057331  1.013318
# 4              0.028844        3.566784            0.043443  1.071891
# ..                  ...             ...                 ...       ...
# 171                 NaN             NaN                 NaN -0.357634
# 172            0.047886        4.851991            0.072578  1.077229
# 173            0.025254        4.246150            0.058297  1.043384
# 174            0.156937        4.309733            0.257896  1.163668
# 175            0.028152        5.195346            0.046139  1.021131
#
#      zeta_err  metallicity_class  lepine_spt  lepine_spt_err
# 0    0.019190              Dwarf         NaN             NaN
# 1    0.008093              Dwarf         NaN             NaN
# 2    0.001444              Dwarf         NaN             NaN
# 3    0.007245              Dwarf         NaN             NaN
# 4    0.005586              Dwarf         NaN             NaN
# ..        ...                ...         ...             ...
# 171  0.018352                usd   -2.179916        0.009446
# 172  0.006820              Dwarf         NaN             NaN
# 173  0.005086              Dwarf         NaN             NaN
# 174  0.031341              Dwarf         NaN             NaN
# 175  0.003977              Dwarf         NaN             NaN
#
# [176 rows x 208 columns]

# %%
CaH1 = df['lepine2003_CaH1'].values
CaH2 = df['lepine2003_CaH2'].values
CaH3 = df['lepine2003_CaH3'].values
TiO5 = df['lepine2003_TiO5'].values



spt = df['subtype'].values

# %%
CaH3
# Out:
# array([0.5956706 , 0.49310503, 0.60564156, 0.74038673, 0.6796231 ,
#        1.01228685, 0.61098194, 0.60112445, 0.90160063, 0.63598744,
#        0.55746306, 0.62984395, 0.67132873, 0.5805896 , 0.6662    ,
#        0.57102152, 0.72670998, 0.5695161 , 0.9989808 , 0.96485619,
#        0.48629687, 0.67452175, 0.64055198, 0.57739836, 0.54871609,
#        0.62037694, 0.76252722, 0.66669673, 0.60284142, 0.62754912,
#        0.57624466, 1.00706754, 7.12564235, 0.48119935, 0.61265698,
#        0.58189019, 0.60090741, 0.63069888, 1.00010866, 0.59731097,
#        0.6821149 , 0.66755323, 0.64783628, 0.65972206, 0.587093  ,
#        0.46194045, 0.59879082, 0.56804328, 0.66775582, 0.60134457,
#        0.63533941, 0.64776259, 0.63064657, 0.59846453, 0.56204069,
#        0.63976662, 0.79771803, 0.93751141, 0.56285147, 0.68145375,
#        0.58444342, 0.65099682, 0.7207989 , 0.55674422, 0.6007657 ,
#        0.98714113, 0.59025715, 0.57133195, 0.60334799, 0.57600709,
#        0.64221246, 1.01939343, 0.78277039, 0.46956805, 0.55733442,
#        0.67971844, 0.62584159, 0.98507035, 0.63891815, 0.76520951,
#        0.71670485, 0.41313142, 0.91925299, 0.66585882, 0.57431097,
#        0.73899615, 1.0265019 , 0.62502908, 0.67657006, 0.52273144,
#        0.60232534, 0.92714352, 0.61343539, 0.6151948 , 0.60048337,
#        0.66036944, 0.56341512, 0.7919702 , 0.64876172, 0.72568168,
#        0.58616634, 0.58165999, 0.60240324, 0.59184207, 0.60472735,
#        0.5701347 , 0.49422528, 0.50355665, 0.68297493, 0.59668606,
#        1.01243516, 0.71728259, 0.65896937, 0.76157158, 0.53738241,
#        0.4270414 , 0.96202158, 0.20915268, 0.20688099, 0.20734578,
#        0.71161093, 0.25578931, 0.27141401, 0.43043676, 0.24467134,
#        0.44948838, 0.58179114, 0.27760754, 0.28614341, 0.9614864 ,
#        0.96405359, 0.9620685 , 0.21528043, 0.3022963 , 0.26783817,
#        0.24756074])

# %%
x = np.linspace(0,1.5,1000)

fig, ax = plt.subplots(1,1, figsize=[7,7])
#ax.set_title('Reproduction of Fig. 2 in Lepine (2003)')
ax.scatter(TiO5, CaH3)

ax.plot(x, 0.639 * x**3 - 1.199 * x**2 + 1.161 * x + 0.307)

ax.set_xlim(0, 1.1)
ax.set_ylim(0,1.1)
ax.set_ylabel('CaH3')
ax.set_xlabel('TiO5')
fig.savefig('Lepine_TiO5_relation_2.png')

# %%
fig, ax = plt.subplots(1,1, figsize=[7,7])
#ax.set_title('Reproduction of Fig. 2 in Lepine (2003)')
ax.scatter(TiO5, CaH2)

ax.plot(x, 0.968 * x**3 - 1.358 * x**2 + 1.315 * x - 0.033)

ax.set_xlim(0, 1.1)
ax.set_ylim(0,1.1)
ax.set_ylabel('CaH2')
fig.savefig('Lepine_TiO5_relation_1.png')

# %%
fig, ax = plt.subplots(1,1, figsize=[7,7])
ax.set_title('Reproduction of Fig. 2 in Lepine (2003)')
ax.scatter(TiO5, CaH1)

ax.plot(x, 0.695 * x**3 - 0.818 * x**2 + 0.413 * x + 0.651)

ax.set_xlim(0, 1.1)
ax.set_ylim(0,1.1)
ax.set_ylabel('CaH1')
fig.savefig('Lepine_TiO5_relation_0.png')

# %%
fig, ax = plt.subplots(3,1, figsize=[7,21])

x = np.linspace(0,1.5,1000)

ax[0].set_title('Reproduction of Fig. 2 in Lepine (2003)')
ax[0].scatter(TiO5, CaH1)
ax[0].set_xlim(0, 1.1)
ax[0].set_ylim(0,1.1)
ax[0].set_ylabel('CaH1')

ax[0].plot(x, 0.695 * x**3 - 0.818 * x**2 + 0.413 * x + 0.651)

ax[1].scatter(TiO5, CaH2)
ax[1].set_xlim(0, 1.1)
ax[1].set_ylim(0,1.1)
ax[1].set_ylabel('CaH2')

ax[1].plot(x, 0.968 * x**3 - 1.358 * x**2 + 1.315 * x - 0.033)

ax[2].scatter(TiO5, CaH3)
ax[2].set_xlim(0, 1.1)
ax[2].set_ylim(0,1.1)
ax[2].set_ylabel('CaH3')

ax[2].plot(x, 0.639 * x**3 - 1.199 * x**2 + 1.161 * x + 0.307)

ax[2].set_xlabel('TiO5')

fig.savefig('Lepine_TiO5_relation.png')

plt.show()

# %%
plt.figure(figsize=[7,7])
plt.scatter(spt, CaH3)
#plt.title('Recreation of Figure 3 from Lepine (2003)')
plt.ylim(0, 1)
#plt.xlabel('M Subtype')
plt.ylabel('CaH3')

plt.savefig('Lepine_spt_relation_1.png')
plt.show()

# %%
plt.figure(figsize=[7,7])
plt.scatter(spt, CaH2)
plt.title('Recreation of Figure 3 from Lepine (2003)')
plt.ylim(0, 1)
#plt.xlabel('M Subtype')
plt.ylabel('CaH2')

plt.savefig('Lepine_spt_relation_0.png')
plt.show()

# %%
plt.figure(figsize=[7,7])
plt.scatter(spt, TiO5)
#plt.title('Recreation of Figure 3 from Lepine (2003)')
plt.ylim(0, 1)
plt.xlabel('M Subtype')
plt.ylabel('TiO5')

plt.savefig('Lepine_spt_relation_2.png')
plt.show()

# %%
Rba = df['kirkpatrick_Rb-a'].values

# %%
Rbb = df['kirkpatrick_Rb-b'].values

# %%
Naa = df['kirkpatrick_Na-a'].values

# %%
Nab = df['kirkpatrick_Na-b'].values

# %%
Csa = df['kirkpatrick_Cs-a'].values

# %%
Csb = df['kirkpatrick_Cs-b'].values

# %%
fig, ax = plt.subplots(3,2, figsize=[12, 18])


for axis in ax:
    for a in axis:
        a.set_xlim(6, 18)
        a.set_xlabel('M Subtype')
        a.set_ylabel('Index')

ax[0][0].scatter(spt, Rba)
ax[0][0].set_title('Rb-a')
ax[0,0].set_ylim(1, 2.2)

ax[0][1].scatter(spt, Rbb)
ax[0,1].set_title('Rb-b')
ax[0,1].set_ylim(1, 2.4)

ax[1][0].scatter(spt, Naa)
ax[1,0].set_title('Na-a')
ax[1,0].set_ylim(1, 1.5)

ax[1][1].scatter(spt, Nab)
ax[1,1].set_title('Na-b')
#ax[1,1].set_ylim(1, 1.6)

ax[2][0].scatter(spt, Csa)
ax[2,0].set_title('Cs-a')
ax[2,0].set_ylim(1.1, 1.8)

ax[2][1].scatter(spt, Csb)
ax[2,1].set_title('Cs-b')
ax[2,1].set_ylim(1, 1.5)

fig.savefig('kirkpatrick_alkali_lines.png')

fig.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
TiOa = df['kirkpatrick_TiO-a'].values
TiOb = df['kirkpatrick_TiO-b'].values
VOa = df['kirkpatrick_VO-a'].values
VOb = df['kirkpatrick_VO-b'].values

# %%
fig, ax = plt.subplots(2,2, figsize=[12, 12])


for axis in ax:
    for a in axis:
        a.set_xlim(6, 18)
        a.set_xlabel('M Subtype')
        a.set_ylabel('Index')
        
ax[0,0].scatter(spt, TiOa)
ax[0,0].set_title('TiO-a')
ax[0,0].set_ylim(0.8, 2.8)

ax[0,1].scatter(spt, TiOb)
ax[0,1].set_title('TiO-b')
ax[0,1].set_ylim(0.7, 2)

ax[1, 0].scatter(spt, VOa)
ax[1,0].set_title('VO-a')
ax[1,0].set_ylim(0.6,1.3)

ax[1,1].scatter(spt, VOb)
ax[1,1].set_title('VO-b')
ax[1,1].set_ylim(0.9, 1.8)

fig.savefig('kirkpatrick_oxide_ratios.png')

fig.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
CrHa = df['kirkpatrick_CrH-a'].values
CrHb = df['kirkpatrick_CrH-b'].values
FeHa = df['kirkpatrick_FeH-a'].values
FeHb = df['kirkpatrick_FeH-b'].values

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=[6, 12])

ax1.scatter(spt, CrHa)
ax1.set_title('CrH-a')
ax1.set_xlim(6, 18)
ax1.set_ylim(0.9, 2.3)
ax1.set_ylabel('Index')
ax1.set_xlabel('M Subtype')

ax2.scatter(spt, FeHa)
ax2.set_title('FeH-a')
ax2.set_xlim(6, 18)
ax2.set_ylim(1, 1.6)
ax2.set_ylabel('Index')
ax2.set_xlabel('M Subtype')

fig.savefig('kirkpatrick_hydride_ratios.png')

fig.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
fig, ax = plt.subplots(2,2, figsize=[12, 12])


for axis in ax:
    for a in axis:
        a.set_xlim(6, 18)
        a.set_xlabel('M Subtype')
        a.set_ylabel('Index')
        
ax[0,0].scatter(spt, Rbb/TiOb)
ax[0,0].set_title('Rb-b/TiO-b')
ax[0,0].set_ylim(0.4, 2.7)

ax[0,1].scatter(spt, Rbb/VOb)
ax[0,1].set_title('Rb-b/VO-b')
ax[0,1].set_ylim(0.6, 2.3)

ax[1, 0].scatter(spt, Csa/TiOb)
ax[1,0].set_title('Cs-a/TiO-b')
ax[1,0].set_ylim(0.5,2)

ax[1,1].scatter(spt, Csa/VOb)
ax[1,1].set_title('Cs-a/VO-b')
ax[1,1].set_ylim(0.7, 1.7)

fig.savefig('kirkpatrick_alkali_oxide_ratio.png')

fig.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
CaH = CaH2 + CaH3

lepine_spt = 1.4 * CaH**2 - 10. * CaH + 12.4

plt.scatter(spt, lepine_spt)

plt.ylim(-3, 10)
plt.plot(arr, arr)
plt.show()

# %%
fig, ax = plt.subplots(2,2, figsize=[12, 12])

arr = np.linspace(-2.5, 10, 10000)

for axis in ax:
    
    for a in axis:
        
        a.plot(arr, arr)
        a.set_xlabel('Subtype from Standard Comparison')
        a.set_ylim(-5, 10)

ax[0,0].scatter(spt, df['gizis_CaH2_spt'])
ax[0,0].set_ylabel('Gizis CaH2 Subtype')
ax[0,0].set_title('Gizis CaH2 Spt vs Chi2 Spt')

ax[0,1].scatter(spt, df['gizis_CaH3_spt'])
ax[0,1].set_ylabel('Gizis CaH3 Subtype')
ax[0,1].set_title('Gizis CaH2 Spt vs Chi2 Spt')

ax[1,0].scatter(spt, df['gizis_TiO5_spt'])
ax[1,0].set_ylabel('Gizis TiO5 Subtype')
ax[1,0].set_title('Gizis TiO5 Spt vs Chi2 Spt')

ax[1,1].scatter(spt, lepine_spt)
ax[1,1].set_ylabel('Lepine Subtype')
ax[1,1].set_title('Lepine Spt vs Chi2 Spt')

fig.savefig('spt_comparison.png')

fig.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
zeta = df['zeta'].values

zeta1 = zeta[ np.abs(zeta) < 2 ]

plt.figure(figsize=[12,7])
hist = plt.hist(zeta1, bins=100)
plt.title("Histogram of Lepine's Zeta")
plt.xlabel('Lepine Zeta')
plt.ylabel('Count')

plt.savefig('zeta_hist.png')

plt.show()

# %%
np.histogram(zeta)
# Out:
# (array([175,   0,   0,   0,   0,   0,   0,   0,   0,   1]),
#  array([-2.42220734,  4.39800937, 11.21822608, 18.03844278, 24.85865949,
#         31.67887619, 38.4990929 , 45.3193096 , 52.13952631, 58.95974302,
#         65.77995972]))

# %%
#        -4.51841638e-01, -5.77779124e+00,  8.62430828e-02, -2.70795146e+00,
#        -5.68952627e+00, -2.46730114e+00, -4.36093533e-01, -8.36833212e-01,
#        -8.42058646e-01, -1.89019122e-01, -1.28421076e+00, -1.30906954e+00,
#        -2.32152340e+00, -1.91266725e+00, -3.52529779e+00, -2.64618549e-01,
#        -2.95921133e+00, -1.33991145e+00, -6.33712104e+00, -9.48769987e-02,
#        -9.47921309e-01, -9.05390468e+00, -2.31488299e+00,  1.25017325e-01,
#        -6.02220989e+00, -6.89112762e-01, -1.98075615e+00, -4.50167676e-02,
#        -1.78122022e-03, -3.95234551e+00, -9.13760289e-01, -1.29382061e+00,
#        -4.55572914e+00, -2.52727420e-01, -4.50502031e+00, -2.08150429e+00,
#        -4.88589579e+00, -6.10966756e+00, -1.57666334e+00, -2.69970649e+00,
#        -2.93909527e-01, -6.58953242e+00, -9.12694512e-01, -1.21380291e+01,
#        -3.39854417e-01, -4.74691953e+00, -4.27799347e+00, -8.90623651e-02,
#        -3.48105311e+00, -3.07977973e+00,  2.40594575e-02, -1.28105186e+00,
#        -4.23837267e+00, -1.13004731e-01, -1.90134945e-01, -1.22775823e-01,
#        -5.46552231e+00, -4.46182248e+00, -5.28427640e+00, -3.60880244e+00])

# %%
plt.figure(figsize=[12, 7])
plt.title('Halpha (6563 Angstrom) EW vs Subtype')
plt.scatter(spt, Halpha)
plt.ylim(-25, 1)
plt.ylabel('Halpha EW (Angstrom)')
plt.xlabel('M Subtype')

plt.savefig('Halpha_spt.png')
plt.show()

# %%
hastrings = df['LiI_EW'].values

LiI = []
for string in hastrings:
    
    numstring = string.split(' ')[0]
    
    num = float(numstring)
    
    LiI.append(num)
    
LiI = np.array(LiI)

# %%
plt.figure(figsize=[12, 7])
plt.title('Li I (6708 Angstrom) EW vs Subtype')
plt.scatter(spt, LiI)
#plt.ylim(-25, 1)
plt.ylabel('Li I EW (Angstrom)')
plt.xlabel('M Subtype')

plt.savefig('LiI_spt.png')
plt.show()

# %%
hastrings = df['RbIb_EW'].values

RbI = []
for string in hastrings:
    
    numstring = string.split(' ')[0]
    
    try:
        num = float(numstring)
    except:
        num = np.nan
    
    RbI.append(num)
    
RbI = np.array(RbI)

# %%
plt.figure(figsize=[12, 7])
plt.title('Rb I (7948 Angstrom) EW vs Subtype')
plt.scatter(spt, RbI)
plt.ylim(-3, 3)
plt.ylabel('Rb I EW (Angstrom)')
plt.xlabel('M Subtype')

plt.savefig('RbI_spt.png')
plt.show()

# %%
hastrings = df['CsIa_EW'].values

CsI = []
for string in hastrings:
    
    numstring = string.split(' ')[0]
    
    try:
        num = float(numstring)
    except:
        num = np.nan
    
    CsI.append(num)
    
CsI = np.array(CsI)

# %%
plt.figure(figsize=[12, 7])
plt.title('Cs I (8521 Angstrom) EW vs Subtype')
plt.scatter(spt, CsI)
#plt.ylim(-25, 1)
plt.ylabel('Cs I EW (Angstrom)')
plt.xlabel('M Subtype')

plt.savefig('CsI_spt.png')
plt.show()
