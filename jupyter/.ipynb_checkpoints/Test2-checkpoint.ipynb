# %%
import kastclassify

import glob
# Out:
# Adding 145 sources from /home/ryan/code/splat/resources/Spectra/Public/LRIS-RED/ to spectral database
# Adding 89 sources from /home/ryan/code/splat/resources/Spectra/Public/MAGE/ to spectral database
# Adding 2404 sources from /home/ryan/code/splat/resources/Spectra/Public/SPEX-PRISM/ to spectral database

# %%
#load Kast spectra

file_path = '/home/ryan/projects/CoolStars/data/RED/'

suffix = '*.fits'

filepaths = glob.glob(file_path + suffix)

# %%
kastclassify.core.classify(filepaths, 'kast_spectra_calculations_20200823.csv', infile='kast_spectra_calculations_20200823.csv' ,diag_path='/home/ryan/projects/CoolStars/TestingPNGs/20200823/')
# Out:
# Path /home/ryan/projects/CoolStars/TestingPNGs/20200823/ already exists
# Saving diagnostic plots to /home/ryan/projects/CoolStars/TestingPNGs/20200823/
# Path /home/ryan/projects/CoolStars/TestingPNGs/20200823//kastRED_J0300-0746_20170823/ already exists
# Reading in /home/ryan/projects/CoolStars/data/RED/kastRED_J0300-0746_20170823.fits
# Classifying by standard comparison...
# Done!
# Measuring indices...
# Mesuring index set lepine2007...
# Done!
# Mesuring index set lepine2003...
# Done!
# Mesuring index set gizis...
# Done!
# Mesuring index set reid...
# Done!
# Mesuring index set kirkpatrick...
# Done!
# Mesuring index set burgasser...
# Done!
# Mesuring index set martin...
# Done!
# Done!
# Measuring Equivalent Widths...
# Measuring EW for RbIa...
# Done!
# Measuring EW for RbIb...
# Done!
# Measuring EW for NaIa...
# Done!
# Measuring EW for NaIb...
# Done!
# Measuring EW for CsIa...
# Done!
# Measuring EW for CsIb...
# Done!
# Measuring EW for Halpha...
# Done!
# ...
